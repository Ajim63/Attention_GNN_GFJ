# %%
# Load and preview dataset
import datetime
import pandas as pd
import numpy as np

# %%
Synthetic = pd.read_csv('Synthetic_Data.csv', parse_dates=['date'])
Synthetic['ID'] = Synthetic.groupby(["country", "Series", 'S_type']).ngroup()
Synthetic.set_index('date', inplace =True)

Synthetic['ret'] = Synthetic.groupby('ID')['value'].pct_change()
Synthetic.dropna(inplace= True)

# %%
Synthetic_char = Synthetic[['country_gdp_factor', 'weekend_boost_factor','product_linear_trend','random_seris_type',
                            'white_noise', 'holiday_trend_factor', 'eu_industry_product_factor', 'product_seasonal_trend_factor',
                            'random_series_factor', 'wavelength', 'amplitude', 'phase', 'ID']]

Synthetic_char= Synthetic_char.reset_index().set_index(['date', 'ID'])

Synthetic_ret = Synthetic[['ID', 'ret']].pivot(columns='ID', values='ret')
Synthetic_val = Synthetic[['ID', 'value']].pivot(columns='ID', values='value')

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import networkx as nx
from networkx.algorithms import bipartite
import copy
from sklearn.preprocessing import StandardScaler
import scipy.special as special
import scipy.sparse as sp


import os


import tensorflow as tf
#import tensorflow_addons as tfa
import keras

from tensorflow.keras import backend as K
from tensorflow.keras.models import Sequential
#from tensorflow.keras.layers import Dense, GRU, Input
from tensorflow.keras.optimizers import SGD, Adam


from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Input, Dropout, Dense, LeakyReLU, GRU, Concatenate, Reshape, Softmax, Attention
from tensorflow.keras.layers import LSTM, GRU
from tensorflow.keras import activations
from tensorflow.keras.models import Model
#from keras.layers import LeakyReLU

from spektral.layers import  GCSConv, DiffusionConv, GATConv, ARMAConv, GCNConv

from tensorflow.keras.regularizers import l2
# Out:
# Using TensorFlow backend.

# %%
def generate_graph_seq2seq_io_data(
        df, x_offsets, y_offsets, add_time_in_day=True, add_day_in_week=False, scaler=None
):
    """
    Generate samples from
    :param df:
    :param x_offsets:
    :param y_offsets:
    :param add_time_in_day:
    :param add_day_in_week:
    :param scaler:
    :return:
    # x: (epoch_size, input_length, num_nodes, input_dim)
    # y: (epoch_size, output_length, num_nodes, output_dim)
    """

    num_samples, num_nodes = df.shape
    data = np.expand_dims(df.values, axis=-1)
    data_list = [data]
    if add_time_in_day:
        time_ind = (df.index.values - df.index.values.astype("datetime64[D]")) / np.timedelta64(1, "D")
        time_in_day = np.tile(time_ind, [1, num_nodes, 1]).transpose((2, 1, 0))
        data_list.append(time_in_day)
    if add_day_in_week:
        day_in_week = np.zeros(shape=(num_samples, num_nodes, 7))
        day_in_week[np.arange(num_samples), :, df.index.dayofweek] = 1
        data_list.append(day_in_week)

    data = np.concatenate(data_list, axis=-1)
    # epoch_len = num_samples + min(x_offsets) - max(y_offsets)
    x, y = [], []
    # t is the index of the last observation.
    min_t = abs(min(x_offsets))
    max_t = abs(num_samples - abs(max(y_offsets)))  # Exclusive
    for t in range(min_t, max_t):
        x_t = data[t + x_offsets, ...]
        y_t = data[t + y_offsets, ...]
        x.append(x_t)
        y.append(y_t)
    x = np.stack(x, axis=0)
    y = np.stack(y, axis=0)
    return x, y



def plot_loss(dic):
    plt.figure(figsize=(12,5))
    #plt.subplot(1, 2, 1)
    plt.plot(dic['loss'], label='Training loss ')
    plt.plot(dic['val_loss'], label='Validation loss ')
    plt.legend(frameon=False)
    plt.title('train and validation loss')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.show()


    
def MSE(original, imputed):
    # calculate Mean Squared Error
    return np.square(original-imputed).mean()

def MPE(y_true, y_pred, threshold=0.1):
    v = np.copy(y_true)
    np.place(v, v==0, threshold)
    #v = np.clip(np.abs(y_true), threshold, None)
    diff = np.abs((y_true - y_pred) / v)
    return np.mean(diff, axis=-1).mean()

"""
def R_squared(original, predicted):
    Differ = np.square(original-predicted)
    m = np.mean(original) 
    denom = np.square(original - m)
    R_sq = 1 - ((Differ.sum())/denom.sum())
    return R_sq
"""
def R_squared(original, predicted):
    Differ = np.square(original-predicted)
    #m = np.mean(original) 
    denom = np.square(original)
    R_sq = 1 - ((Differ.sum())/denom.sum())
    return R_sq

def Get_performance(Y_true, Y_pred): 
    print ("R2 : ", np.round(R_squared(Y_true, Y_pred), 4))
    print ("MSE",  np.round(MSE(Y_true, Y_pred), 4))
    print ("MPE", np.round(MPE(Y_true, Y_pred), 4))
    
    return (np.round(R_squared(Y_true, Y_pred), 4), np.round(MSE(Y_true, Y_pred), 4), np.round(MPE(Y_true, Y_pred), 4)) 
        

def mae(y_true, y_pred):
    return np.mean(np.abs(y_pred - y_true))

def rmse(y_true, y_pred):
    return np.sqrt(np.mean(np.square(y_pred - y_true)))

def mape(y_true, y_pred, threshold=0.1):
    v = np.clip(np.abs(y_true), threshold, None)
    diff = np.abs((y_true - y_pred) / v)
    return 100.0 * np.mean(diff, axis=-1).mean()

def get_metrics(y, yp):
    return {
        "rmse": np.round(rmse(y, yp), 4),
        "mae": np.round(mae(y, yp), 4),
        "mape": np.round(mape(y, yp),4),
        #"MPE": np.round(MPE(y, yp), 4),
        #"R2": np.round(R_squared(y, yp),4)
        
    }

# %%
n_day = len(Synthetic_char.groupby('date').size())
n_firms = len(Synthetic_char.groupby('ID').size())

# %%
#how many time lag I wanna use
n_lag = 36
#how many time period I wanna predict
n_forward = 1

x_offsets = np.sort(np.arange(-n_lag+1, 1, 1))
y_offsets = np.sort(np.arange(1, n_forward+1, 1))

# %%
x, y = generate_graph_seq2seq_io_data(
    Synthetic_ret,
    x_offsets=x_offsets,
    y_offsets=y_offsets,
    add_time_in_day=False,
    add_day_in_week=False,
    )

# %%
x = np.transpose(x, (0, 2, 1, 3))
y = np.transpose(y, (0, 2, 1, 3))

#reshape to made three dimensional tensor
#x = x.reshape(x.shape[0],x.shape[1],x.shape[2] )
y = y.reshape(y.shape[0],y.shape[1],y.shape[2] )

#x = np.transpose(x, (0, 2, 1))
#y = np.transpose(y, (0, 2, 1))



x = x.astype('float32')
y = y.astype('float32')

# %%
x_train = x[:600,:,:]
y_train = y[:600,:,:]



x_val = x[600:800,:,:]
y_val = y[600:800,:,:]


x_test = x[800:,:,:]
y_test = y[800:,:,:]

# %%
y_test.shape
# Out:
# (259, 50, 1)

# %%
data_shape = x.shape

# %%
data_shape
# Out:
# (1059, 50, 36, 1)

# %%
learning_rate = 0.001
batch_size =24
epochs = 100
seed = 42
verbose = 1

# %%
tf.keras.backend.clear_session()

# %%
train_result = np.empty_like(y_train)
val_result = np.empty_like(y_val)
test_result = np.empty_like(y_test)

for i in range(0, x_train.shape[1]):
#for i in range(0, 4):
    print("Firm ID+++++=======   ", i)
    tf.keras.backend.clear_session()
    
    inputs = Input(shape=(data_shape[2],data_shape[3], ))
    LSTM_1 = LSTM(10, activation="tanh", dropout=0.2, return_sequences=True)(inputs)
    LSTM_2 = LSTM(8, activation="relu", dropout=0.2, return_sequences=False)(LSTM_1)
    #dense_out = Dense(8, activation='linear')(LSTM_2)
    #dense_out = Dropout(0.2)(dense_out)
    outputs = Dense(1)(LSTM_2)
    
    model = Model(inputs=inputs, outputs=outputs)   
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')
    model.summary()
    
    model.fit((x_train[:,i,:,:]), (y_train[:,i,:]), epochs= epochs, batch_size= batch_size,
              validation_data=(x_val[:,i,:,:], y_val[:,i,:]),
              callbacks=[EarlyStopping(#monitor="val_mean_absolute_error", 
              monitor="val_loss", patience=10, restore_best_weights=True)])
    
    train_pred = model.predict(x_train[:,i,:,:])
    val_pred = model.predict(x_val[:,i,:,:])
    test_pred = model.predict(x_test[:,i,:,:])
    
    train_result[:,i,:] =  train_pred
    val_result[:,i,:] =  val_pred
    test_result[:,i,:] =  test_pred
# Out:
# Firm ID+++++=======    0
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 36ms/step - loss: 0.0080 - val_loss: 0.0087
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0086
# Epoch 3/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0079 - val_loss: 0.0085
# Epoch 4/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0079 - val_loss: 0.0085
# Epoch 5/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0084
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0084
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0083
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0082
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0081
# Epoch 10/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0079
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0079
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0077
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0075
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0072
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0064
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0059
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0057 - val_loss: 0.0056
# Epoch 24/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0057
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0057
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0060
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 32/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 33/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 36/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 37/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 38/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 39/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 40/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0055
# Epoch 41/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0056
# Epoch 42/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 43/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 44/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0056
# Epoch 45/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0055
# Epoch 46/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0055
# Epoch 47/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0056
# Epoch 48/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 49/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0055
# Firm ID+++++=======    1
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 36ms/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 3/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 4/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 5/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0094 - val_loss: 0.0100
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0093 - val_loss: 0.0099
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0093 - val_loss: 0.0099
# Epoch 10/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0093 - val_loss: 0.0099
# Epoch 11/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0092 - val_loss: 0.0098
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0092 - val_loss: 0.0097
# Epoch 13/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0090 - val_loss: 0.0095
# Epoch 14/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0090 - val_loss: 0.0094
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0095
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0095
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0093
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0092
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 23/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0084 - val_loss: 0.0087
# Epoch 24/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084 - val_loss: 0.0088
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0085
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0084
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0082
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0079
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0078
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 32/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 33/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0073
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0077
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 36/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0072
# Epoch 37/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0070
# Epoch 38/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0071
# Epoch 39/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0070
# Epoch 40/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 41/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0069
# Epoch 42/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 43/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0067
# Epoch 44/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0067
# Epoch 45/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0067
# Epoch 46/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0077
# Epoch 47/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 48/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 49/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0067
# Epoch 50/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0068
# Epoch 51/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0068
# Epoch 52/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0070
# Epoch 53/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0069
# Epoch 54/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0069
# Epoch 55/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0069
# Firm ID+++++=======    2
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 37ms/step - loss: 0.0102 - val_loss: 0.0103
# Epoch 2/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0101 - val_loss: 0.0099
# Epoch 3/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0097 - val_loss: 0.0095
# Epoch 4/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0093 - val_loss: 0.0091
# Epoch 5/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0091 - val_loss: 0.0090
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0091 - val_loss: 0.0089
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 10/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0090
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0088
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0088
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 24/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0087
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0087
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0087
# Epoch 32/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 33/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0086
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0087
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0086
# Epoch 36/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 37/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0086
# Epoch 38/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 39/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 40/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 41/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 42/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 43/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0085
# Epoch 44/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0085
# Epoch 45/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 46/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 47/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084 - val_loss: 0.0084
# Epoch 48/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0084
# Epoch 49/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084 - val_loss: 0.0083
# Epoch 50/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 51/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0083 - val_loss: 0.0082
# Epoch 52/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0083 - val_loss: 0.0082
# Epoch 53/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0081
# Epoch 54/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0082
# Epoch 55/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0083 - val_loss: 0.0081
# Epoch 56/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0080
# Epoch 57/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0079
# Epoch 58/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0080
# Epoch 59/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0079
# Epoch 60/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0078
# Epoch 61/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0077
# Epoch 62/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0076
# Epoch 63/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0076
# Epoch 64/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0075
# Epoch 65/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 66/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 67/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0072
# Epoch 68/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 69/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0071
# Epoch 70/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0072
# Epoch 71/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0070
# Epoch 72/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0070
# Epoch 73/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 74/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 75/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0069
# Epoch 76/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0068
# Epoch 77/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0067
# Epoch 78/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0067
# Epoch 79/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0067
# Epoch 80/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 81/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0066
# Epoch 82/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0067
# Epoch 83/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0066
# Epoch 84/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0068
# Epoch 85/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0066
# Epoch 86/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0064
# Epoch 87/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 88/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0065
# Epoch 89/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0067
# Epoch 90/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0067
# Epoch 91/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0067
# Epoch 92/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 93/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0064
# Epoch 94/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0064
# Epoch 95/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0066
# Epoch 96/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0065
# Epoch 97/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0064
# Epoch 98/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0064
# Epoch 99/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0064
# Epoch 100/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0064
# Firm ID+++++=======    3
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 36ms/step - loss: 0.0082 - val_loss: 0.0098
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0098
# Epoch 3/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0098
# Epoch 4/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0098
# Epoch 5/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0098
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0097
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0097
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0096
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0096
# Epoch 10/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0095
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0094
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0094
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0092
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0088
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0081
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0078
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0068
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0071
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0071
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0065 - val_loss: 0.0067
# Epoch 24/100
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0063 - val_loss: 0.0066
# Epoch 25/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0065 - val_loss: 0.0066
# Epoch 26/100
# 25/25 [==============================] - 1s 20ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0063
# Epoch 32/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 33/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0064
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0066
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0065
# Epoch 36/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0064
# Epoch 37/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 38/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 39/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0063
# Epoch 40/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0063
# Epoch 41/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0065 - val_loss: 0.0063
# Firm ID+++++=======    4
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 36ms/step - loss: 0.0100 - val_loss: 0.0082
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0098 - val_loss: 0.0082
# Epoch 3/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0098 - val_loss: 0.0081
# Epoch 4/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0098 - val_loss: 0.0080
# Epoch 5/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0097 - val_loss: 0.0080
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0098 - val_loss: 0.0080
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0097 - val_loss: 0.0079
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0096 - val_loss: 0.0078
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0096 - val_loss: 0.0077
# Epoch 10/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0097 - val_loss: 0.0077
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0096 - val_loss: 0.0076
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0095 - val_loss: 0.0075
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0072
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0069
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084 - val_loss: 0.0063
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0083 - val_loss: 0.0061
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0060
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0059
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0061
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0056
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0056
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0056
# Epoch 24/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0057
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0057
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0056
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0057
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0057
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0056
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0058
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0056
# Epoch 32/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0055
# Epoch 33/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0056
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0056
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0056
# Epoch 36/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0058
# Epoch 37/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0056
# Epoch 38/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0056
# Epoch 39/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0055
# Epoch 40/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0055
# Epoch 41/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0059
# Epoch 42/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0056
# Epoch 43/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0057
# Epoch 44/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0057
# Epoch 45/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0055
# Epoch 46/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0055
# Epoch 47/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0057
# Epoch 48/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0056
# Epoch 49/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0056
# Epoch 50/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0057
# Firm ID+++++=======    5
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 37ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 3/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 4/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 5/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0077
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0076
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0075
# Epoch 10/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0074
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0072
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0072
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0071
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0069
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0064
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0059
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0059
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0052
# Epoch 24/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0052
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 32/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0051
# Epoch 33/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0050
# Epoch 36/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0050
# Epoch 37/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0051
# Epoch 38/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0058 - val_loss: 0.0050
# Firm ID+++++=======    6
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 36ms/step - loss: 0.0087 - val_loss: 0.0080
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0080
# Epoch 3/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0080
# Epoch 4/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0080
# Epoch 5/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0079
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0079
# Epoch 10/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0079
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0079
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0079
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0078
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0078
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0077
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084 - val_loss: 0.0076
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0072
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0075
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0070
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0070
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0068
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0067
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0066
# Epoch 24/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0064
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0063
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0063
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0063
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0057
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0055
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0054
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0054
# Epoch 32/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0054
# Epoch 33/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0065 - val_loss: 0.0052
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0054
# Epoch 36/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0053
# Epoch 37/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0052
# Epoch 38/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0051
# Epoch 39/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0052
# Epoch 40/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0053
# Epoch 41/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0053
# Epoch 42/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 43/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0052
# Epoch 44/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0065 - val_loss: 0.0051
# Epoch 45/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0053
# Epoch 46/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 47/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0052
# Epoch 48/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0053
# Firm ID+++++=======    7
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 36ms/step - loss: 0.0106 - val_loss: 0.0088
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0104 - val_loss: 0.0086
# Epoch 3/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0102 - val_loss: 0.0083
# Epoch 4/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0098 - val_loss: 0.0084
# Epoch 5/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0098 - val_loss: 0.0077
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0091 - val_loss: 0.0073
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0091 - val_loss: 0.0072
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0093 - val_loss: 0.0073
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0091 - val_loss: 0.0074
# Epoch 10/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0092 - val_loss: 0.0072
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0092 - val_loss: 0.0072
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0092 - val_loss: 0.0072
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0071
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0073
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0092 - val_loss: 0.0071
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0091 - val_loss: 0.0071
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0071
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0071
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0071
# Epoch 20/100
# 25/25 [==============================] - 1s 22ms/step - loss: 0.0088 - val_loss: 0.0070
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0071
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0070
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0088 - val_loss: 0.0071
# ...
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0094
# Epoch 10/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0089 - val_loss: 0.0093
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0093
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0093
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0094
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0092
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0086 - val_loss: 0.0092
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0091
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0087 - val_loss: 0.0090
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0083 - val_loss: 0.0090
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0090
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0085 - val_loss: 0.0090
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0089
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0091
# Epoch 24/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0088
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084 - val_loss: 0.0088
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0088
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0084 - val_loss: 0.0088
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0088
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0083 - val_loss: 0.0087
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0087
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 32/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 33/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0086
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0085
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0084
# Epoch 36/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0081 - val_loss: 0.0083
# Epoch 37/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0078 - val_loss: 0.0082
# Epoch 38/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0083
# Epoch 39/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0081
# Epoch 40/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0080
# Epoch 41/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0079
# Epoch 42/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0080
# Epoch 43/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0082 - val_loss: 0.0081
# Epoch 44/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0078
# Epoch 45/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0076
# Epoch 46/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 47/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0073
# Epoch 48/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0075
# Epoch 49/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0073
# Epoch 50/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0074
# Epoch 51/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0074
# Epoch 52/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 53/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0070
# Epoch 54/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 55/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0075 - val_loss: 0.0071
# Epoch 56/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0069
# Epoch 57/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 58/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0066
# Epoch 59/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 60/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0065
# Epoch 61/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0066
# Epoch 62/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 63/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0064
# Epoch 64/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0065
# Epoch 65/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0064
# Epoch 66/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 67/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 68/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0067
# Epoch 69/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0065
# Epoch 70/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 71/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0071 - val_loss: 0.0066
# Epoch 72/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0066
# Epoch 73/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0065
# Firm ID+++++=======    48
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 36ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 3/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 4/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 5/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0078
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0077
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0076
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0079
# Epoch 10/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0075
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0075
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0073
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0073
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0071
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0074 - val_loss: 0.0071
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0073 - val_loss: 0.0068
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0066
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0064
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0064
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0061
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0060
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0058
# Epoch 24/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0058
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0056
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0056
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0055
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0054
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0053
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0058
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0068 - val_loss: 0.0055
# Epoch 32/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 33/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0052
# Epoch 34/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0051
# Epoch 35/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 36/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 37/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0053
# Epoch 38/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0065 - val_loss: 0.0053
# Epoch 39/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 40/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0052
# Epoch 41/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0052
# Epoch 42/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0053
# Epoch 43/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0051
# Epoch 44/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0065 - val_loss: 0.0052
# Firm ID+++++=======    49
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 36, 1)]           0
# _________________________________________________________________
# lstm (LSTM)                  (None, 36, 10)            480
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 8)                 608
# _________________________________________________________________
# dense (Dense)                (None, 1)                 9
# =================================================================
# Total params: 1,097
# Trainable params: 1,097
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 25/25 [==============================] - 1s 35ms/step - loss: 0.0080 - val_loss: 0.0105
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0105
# Epoch 3/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0104
# Epoch 4/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0104
# Epoch 5/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0079 - val_loss: 0.0102
# Epoch 6/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0101
# Epoch 7/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0101
# Epoch 8/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0077 - val_loss: 0.0099
# Epoch 9/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0076 - val_loss: 0.0097
# Epoch 10/100
# 25/25 [==============================] - 1s 30ms/step - loss: 0.0075 - val_loss: 0.0095
# Epoch 11/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 12/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0088
# Epoch 13/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0069 - val_loss: 0.0085
# Epoch 14/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0066 - val_loss: 0.0081
# Epoch 15/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0070 - val_loss: 0.0080
# Epoch 16/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0076
# Epoch 17/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0072
# Epoch 18/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0063 - val_loss: 0.0072
# Epoch 19/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0067 - val_loss: 0.0074
# Epoch 20/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0071
# Epoch 21/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0070
# Epoch 22/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0074
# Epoch 23/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0071
# Epoch 24/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0071
# Epoch 25/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0070
# Epoch 26/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0059 - val_loss: 0.0070
# Epoch 27/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 28/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0064 - val_loss: 0.0070
# Epoch 29/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0060 - val_loss: 0.0070
# Epoch 30/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0062 - val_loss: 0.0070
# Epoch 31/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.0061 - val_loss: 0.0070

# %%
get_metrics(y_train.flatten(), train_result.flatten())
# Out:
# {'mae': 0.0595, 'mape': 49.3718, 'rmse': 0.075}

# %%
get_metrics(y_val.flatten(), val_result.flatten())
# Out:
# {'mae': 0.0601, 'mape': 49.6686, 'rmse': 0.0759}

# %%
get_metrics(y_test.flatten(), test_result.flatten())
# Out:
# {'mae': 0.0595, 'mape': 49.2249, 'rmse': 0.0754}

# %%
#np.savetxt('LSTM_test_result.csv', test_result.flatten(), delimiter=",")

# %%
# To read the file into numpy data. 
#np.genfromtxt('LSTM_test_result.csv',delimiter=',')
